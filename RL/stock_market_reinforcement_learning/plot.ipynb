# %%
from __future__ import print_function


import json
import numpy as np
import os
import pandas as pd
import urllib
import math

from pandas import read_csv
from pandas import DataFrame
from matplotlib import pyplot

# %%
data_df = read_csv('../../dataset/bitcoin201901to201905.csv', header=0, index_col=0)
print(data_df.head())

pq_df = read_csv('episode_0.csv', header=None, index_col=0, sep=" ")
df.head()
# Out:
#                   Close       High          Low         Open        Volume
# Timestamp
# 1546300800  3697.730000  3700.0000  3691.000002  3696.202300   7095.559257
# 1546301700  3695.179141  3697.9878  3687.024301  3694.186356   2142.803493
# 1546302600  3703.000000  3707.7001  3697.897800  3697.957800  15972.302727
# 1546303500  3703.000000  3711.4200  3703.000000  3703.000044   5796.233350
# 1546304400  3691.603671  3709.9000  3691.603671  3697.977800   1297.983519
#                  1    2    3          4           5
# 0
# 1546357500:  SHORT  0.0  1.0  LONG:0.00  SHORT:1.00
# 1546358400:  SHORT  0.0  1.0  LONG:0.00  SHORT:1.00
# 1546359300:   LONG -0.0  1.0  LONG:1.00  SHORT:0.00
# 1546360200:  SHORT -0.0  1.0  LONG:0.00  SHORT:1.00
# 1546361100:   LONG -0.0  1.0  LONG:1.00  SHORT:0.00

# %%
# %matplotlib notebook

#pyplot.plot( data_df['Close'].values, label='data')
pyplot.plot( pq_df[2].values, label='cum')
pyplot.legend()
pyplot.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib.pyplot as plt

fig,left_axis=plt.subplots()
#fig.subplots_adjust(right_axis=0,75)
 
right_axis = left_axis.twinx()

left_axis.plot( pq_df[2].values, 'b-' , label='cum')
right_axis.plot(data_df['Close'].values, 'r-', label='data')
pyplot.legend()
pyplot.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
