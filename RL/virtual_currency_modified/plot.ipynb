# %%
from __future__ import print_function


import json
import numpy as np
import os
import pandas as pd
import urllib
import math

from pandas import read_csv
from pandas import DataFrame
from matplotlib import pyplot

# %%
data_df = read_csv('../../dataset/dataset-USDT_BTC-20180101-20190617-half-hourly.csv', header=0, index_col=0)
print(data_df.head())

pq_df = read_csv('episode_0.csv', header=None, index_col=0, sep=" ")
pq_df.tail()
# Out:
#                    Close     High           Low     Open        Volume
# Timestamp
# 1514764800  13600.000000  13800.0  13483.913421  13800.0  2.036139e+06
# 1514766600  13563.425598  13700.0  13536.063256  13600.0  2.019440e+06
# 1514768400  13600.000000  13700.0  13483.913421  13564.0  1.649584e+06
# 1514770200  13266.720000  13619.9  13211.000000  13600.0  1.628182e+06
# 1514772000  13307.940150  13444.0  13255.988825  13301.0  1.063081e+06
#                 1     2     3          4           5
# 0
# 1517164200:  LONG -0.18  0.90  LONG:1.00  SHORT:0.00
# 1517166000:  LONG -0.18  0.89  LONG:1.00  SHORT:0.00
# 1517167800:  LONG -0.18  0.89  LONG:1.00  SHORT:0.00
# 1517169600:  LONG -0.18  0.90  LONG:1.00  SHORT:0.00
# 1517171400:  LONG -0.18  0.90  LONG:1.00  SHORT:0.00

# %%
# %matplotlib notebook

#pyplot.plot( data_df['Close'].values, label='data')
pyplot.plot( pq_df[2].values, label='cum')
pyplot.legend()
pyplot.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib.pyplot as plt

fig,left_axis=plt.subplots()
#fig.subplots_adjust(right_axis=0,75)
 
right_axis = left_axis.twinx()

left_axis.plot( pq_df[2].values, 'b-' , label='cum profit')
right_axis.plot(data_df['Close'].values[1:2000], 'r-', label='market')
pyplot.legend()
pyplot.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
